# %%
import pandas as pd 
df=pd.read_csv(r'basketOutput.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction      20507 non-null  int64
#  1   Item             20507 non-null  object
#  2   period_day       20507 non-null  object
#  3   weekday_weekend  20507 non-null  object
#  4   month            20507 non-null  int64
#  5   day              20507 non-null  object
#  6   hour             20507 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
import inflect
import calendar
def inputNumber(x):
    return inflect.engine().number_to_words(x)
df['Transaction']=df['Transaction'].apply(inputNumber)
df['hour']=df['hour'].apply(inputNumber)
df['month'] = df['month'].apply(lambda x: calendar.month_abbr[x])

# %%
df
# Out:
#                                        Transaction           Item period_day  \
# 0                                              one          bread    morning
# 1                                              two   scandinavian    morning
# 2                                              two   scandinavian    morning
# 3                                            three  hot chocolate    morning
# 4                                            three            jam    morning
# ...                                            ...            ...        ...
# 20502    nine thousand, six hundred and eighty-two         coffee  afternoon
# 20503    nine thousand, six hundred and eighty-two            tea  afternoon
# 20504  nine thousand, six hundred and eighty-three         coffee  afternoon
# 20505  nine thousand, six hundred and eighty-three         pastry  afternoon
# 20506   nine thousand, six hundred and eighty-four      smoothies  afternoon
#
#       weekday_weekend month     day      hour
# 0             weekend   Oct  Sunday      nine
# 1             weekend   Oct  Sunday       ten
# 2             weekend   Oct  Sunday       ten
# 3             weekend   Oct  Sunday       ten
# 4             weekend   Oct  Sunday       ten
# ...               ...   ...     ...       ...
# 20502         weekend   Sep  Monday  fourteen
# 20503         weekend   Sep  Monday  fourteen
# 20504         weekend   Sep  Monday  fourteen
# 20505         weekend   Sep  Monday  fourteen
# 20506         weekend   Sep  Monday   fifteen
#
# [20507 rows x 7 columns]

# %%
df.to_csv('basket.csv')
